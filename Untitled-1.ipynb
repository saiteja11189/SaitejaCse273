# %%
import numpy as np
a= np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
b= np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(a.shape)
# Out:
# (3,)

# %%
print(b.shape)
# Out:
# (2, 3)
