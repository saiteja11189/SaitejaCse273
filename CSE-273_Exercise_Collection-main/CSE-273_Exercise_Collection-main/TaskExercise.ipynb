# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Product_ID": list(range(1,21)),
    "Category": [
        "Electronics","Clothing","Electronics","Accessories","Clothing",
        "Electronics","Accessories","Clothing","Electronics","Accessories",
        "Clothing","Electronics","Accessories","Clothing","Electronics",
        "Accessories","Clothing","Electronics","Accessories","Clothing"
    ],
    
    "Price":[
        500,50,700,30,60,650,40,55,720,35,
        65,680,45,70,750,50,80,800,60,90
    ],

    "Units_Sold":[
        40,120,35,200,110,45,180,130,38,210,
        115,50,170,125,42,190,140,36,175,135
    ],

    "Ad_Spend":[
        2000,800,2500,500,900,2400,600,850,2600,550,
        950,2300,650,1000,2700,700,1100,2800,750,1200
    ],

    "Spotify":[
        2,4,3,5,4,3,5,4,3,5,
        4,3,5,4,3,5,4,3,5,4
    ]
}

# %%
# Create DataFrame
df = pd.DataFrame(data)

# %%
print("Dataset")
print(df)
# Out:
# Dataset
#     Product_ID     Category  Price  Units_Sold  Ad_Spend  Spotify
# 0            1  Electronics    500          40      2000        2
# 1            2     Clothing     50         120       800        4
# 2            3  Electronics    700          35      2500        3
# 3            4  Accessories     30         200       500        5
# 4            5     Clothing     60         110       900        4
# 5            6  Electronics    650          45      2400        3
# 6            7  Accessories     40         180       600        5
# 7            8     Clothing     55         130       850        4
# 8            9  Electronics    720          38      2600        3
# 9           10  Accessories     35         210       550        5
# 10          11     Clothing     65         115       950        4
# 11          12  Electronics    680          50      2300        3
# 12          13  Accessories     45         170       650        5
# ...

# %%
# Statistical Analysis


print("\nMean")
print(df.mean(numeric_only=True))

print("\nMedian")
print(df.median(numeric_only=True))

print("\nStandard Deviation")
print(df.std(numeric_only=True))

print("\nCorrelation")
print(df.corr(numeric_only=True))
# Out:
# Mean
# Product_ID      10.5
# Price          276.5
# Units_Sold     114.3
# Ad_Spend      1392.5
# Spotify          3.9
# dtype: float64
#
# Median
# Product_ID     10.5
# Price          67.5
# Units_Sold    122.5
# Ad_Spend      975.0
# Spotify         4.0
# dtype: float64
#
# Standard Deviation
# Product_ID      5.916080
# Price         312.995292
# Units_Sold     61.884527
# Ad_Spend      843.594284
# Spotify         0.911910
# dtype: float64
#
# Correlation
#             Product_ID     Price  Units_Sold  Ad_Spend   Spotify
# Product_ID    1.000000 -0.065516    0.185735 -0.010282  0.243894
# Price        -0.065516  1.000000   -0.894360  0.985986 -0.827395
# Units_Sold    0.185735 -0.894360    1.000000 -0.933312  0.958378
# Ad_Spend     -0.010282  0.985986   -0.933312  1.000000 -0.873337
# Spotify       0.243894 -0.827395    0.958378 -0.873337  1.000000

# %%
# Scatter Plot

plt.figure()
plt.scatter(df["Ad_Spend"], df["Units_Sold"])
plt.title("Ad Spend vs Units Sold")
plt.xlabel("Ad Spend")
plt.ylabel("Units Sold")
plt.show()

# %%
# Bar Chart

plt.figure()
plt.bar(df["Product_ID"], df["Units_Sold"])
plt.title("Units Sold per Product ID")
plt.xlabel("Product ID")
plt.ylabel("Units Sold")
plt.show()

# %%
# Histogram

plt.figure()
plt.hist(df["Price"], bins=10)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
#pie chart
plt.figure()
category_counts = df["Category"].value_counts()
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Product Category Distribution")
plt.show()
