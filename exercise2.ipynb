# %% [markdown]
# Exercise 2

# %%
import numpy as np
Student_details = np.array([
                            [78,85,90],
                            [45,60,55],
                            [88,92,95],
                            [30,40,35], 
                            [65,70,75]])
print(Student_details)
print(Student_details.shape)
print(Student_details.dtype)
print(Student_details.size)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 35]
#  [65 70 75]]
# (5, 3)
# int64
# 15

# %%
import numpy as np
Student_details = np.array([
                            [78,85,90],
                            [45,60,55],
                            [88,92,95],
                            [30,40,35], 
                            [65,70,75]])
print(Student_details[np.array([1])])
print(Student_details[np.array([2])])

print(Student_details[0,1])
# Out:
# [[45 60 55]]
# [[88 92 95]]
# 85

# %% [markdown]
# calculating means and averages

# %%
print(np.sum(Student_details, axis=0))
# Out:
# [306 347 350]
