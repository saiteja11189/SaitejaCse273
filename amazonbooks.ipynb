# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("bestsellers_with_categories_2022_03_27.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         700 non-null    object
#  1   Author       700 non-null    object
#  2   User Rating  700 non-null    float64
#  3   Reviews      700 non-null    int64
#  4   Price        700 non-null    int64
#  5   Year         700 non-null    int64
#  6   Genre        700 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 38.4+ KB

# %%
df.groupby("Author")["Price"].sum().sort_values(ascending=False).head(10)
# Out:
# Author
# American Psychological Association    481
# The College Board                     236
# Gary Chapman                          213
# American Psychiatric Association      210
# Suzanne Collins                       161
# Gallup                                153
# Stephenie Meyer                       153
# Stephen R. Covey                      144
# Jeff Kinney                           125
# J.K. Rowling                          121
# Name: Price, dtype: int64

# %%
df.sort_values("Price", ascending=False).head(10)
# Out:
#                                                   Name  \
# 204  Diagnostic and Statistical Manual of Mental Di...
# 253  Diagnostic and Statistical Manual of Mental Di...
# 43                        The Twilight Saga Collection
# 364                           Hamilton: The Revolution
# 28   The Book of Basketball: The NBA According to T...
# 368         Harry Potter Paperback Box Set (Books 1-7)
# 22   Publication Manual of the American Psychologic...
# 70   Publication Manual of the American Psychologic...
# 170  Publication Manual of the American Psychologic...
# 425  Publication Manual of the American Psychologic...
#
#                                  Author  User Rating  Reviews  Price  Year  \
# 204    American Psychiatric Association          4.5     6679    105  2013
# 253    American Psychiatric Association          4.5     6679    105  2014
# 43                      Stephenie Meyer          4.7     3801     82  2009
# ...

# %%
df.groupby("Author")["User Rating"].sum().sort_values(ascending=False).head(10)
# Out:
# Author
# Jeff Kinney                           67.4
# Gary Chapman                          66.5
# Suzanne Collins                       56.0
# Rick Riordan                          52.5
# American Psychological Association    49.8
# Eric Carle                            49.0
# Dr. Seuss                             48.8
# Dav Pilkey                            44.1
# Don Miguel Ruiz                       42.3
# Stephenie Meyer                       37.4
# Name: User Rating, dtype: float64

# %%
df.groupby("Name")["User Rating"].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# The Very Hungry Caterpillar                                                          49.0
# Publication Manual of the American Psychological Association, 6th Edition            45.0
# The Four Agreements: A Practical Guide to Personal Freedom (A Toltec Wisdom Book)    42.3
# Oh, the Places You'll Go!                                                            39.2
# The 5 Love Languages: The Secret to Love that Lasts                                  38.4
# StrengthsFinder 2.0                                                                  36.0
# How to Win Friends & Influence People                                                32.9
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change         32.5
# Jesus Calling: Enjoying Peace in His Presence (with Scripture References)            29.4
# The Wonderful Things You Will Be                                                     29.4
# Name: User Rating, dtype: float64
